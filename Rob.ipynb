# %%
import os
import csv

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
from scipy.stats import sem
from scipy.stats import linregress

# %%
data_file = "Resources/CaliFire_Rob.csv"
df = pd.read_csv(data_file)
df.head(5)
# Out:
#    Year Fires   Acres
# 0  1987  8062   87000
# 1  1988  8121  191000
# 2  1989  6635   73600
# 3  1990  7283  212100
# 4  1991  6271   23100

# %%
acres_df = df[['Year', 'Acres']]
acres_df = pd.DataFrame(acres_df)
acres_df.head()
# Out:
#    Year   Acres
# 0  1987   87000
# 1  1988  191000
# 2  1989   73600
# 3  1990  212100
# 4  1991   23100

# %%
last_twenty = acres_df['Acres']
last_twenty = pd.DataFrame(last_twenty)
last_twenty
# Out:
#       Acres
# 0     87000
# 1    191000
# 2     73600
# 3    212100
# 4     23100
# 5    191490
# 6    122606
# 7    140792
# 8    121198
# 9    232624
# 10    57788
# 11    92456
# 12   285272
# 13    72718
# 14    90985
# 15   112810
# 16   404328
# 17   168134
# 18    74004
# 19   222896
# 20   434667
# 21   380310
# 22    75960
# 23    25438
# 24    51889
# 25   128956
# 26   114473
# 27   163067
# 28   291282
# 29   244556
# 30   467497
# 31  1063414

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

x_values = acres_df['Year']
y_values = acres_df['Acres']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(1987,2018),fontsize=10,color="red")
plt.title("Acres Burned Per Year")
plt.xlabel('Year')
plt.ylabel('Acres Burned (millions)')
print(f"The r-squared is: {rvalue}")
output_file1 = "Rob_Scatter.png"
plt.savefig(output_file1)
plt.show()
# Out:
# The r-squared is: 0.42114052568757304

# %%
# Create 2 arrays that contains the years and the number of acres burned each year
years = ["1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001", "2002","2003", "2004", "2005", "2006","2007", "2008", "2009", "2010", "2011", "2012","2013", "2014", "2015", "2016", "2017", "2018"]
acres_burned = [87000,191000,73600,212100,23100,191490,122606,140792,121198,232624,57788,92456,285272,72718,90985,112810,404328,168134,74004,222896,434667,380310,75960,25438,51889,128956,114473,163067,291282,244556,467497,1063414]

# Create x_axis
x_axis = np.arange(len(years))
x_axis
colors = ["blue"]

# Create a bar chart based upon the above data
plt.bar(x_axis, acres_burned, color=colors, align="center")

# Create the ticks for our bar chart's x axis
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, years)
plt.xticks(tick_locations, years, rotation = 'vertical')
# Set the limits of the x axis
plt.xlim(-0.75, len(x_axis)-0.25)

# Set the limits of the y axis
plt.ylim(0, max(acres_burned)+50000)
plt.xlim(-1.2, len(x_axis))
# Give the chart a title, x label, and y label
plt.title("Acres Burned Per Year")
plt.xlabel("Years")
plt.ylabel("Acres Burned (millions)")

# Save an image of the chart and print it to the screen
output_file2 = "Rob_Bar.png"
plt.savefig(output_file2)
plt.show()
